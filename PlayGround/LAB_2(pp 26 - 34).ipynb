# %% [markdown]
# ## Basic Feature Engineering

# %%
"""

Three classes of features that can be created from our time series dataset:
1)Date Time Features: these are components of the time step itself for each observation.

2)Lag Feautres: these are the values at prior time steps.

3)Window Features: these are a summary of values over a fixed window of prior time steps.

"""

# %% [markdown]
# ### The goal of feature engineering is to provide strong and ideally simple relationships between inputs and output features so that they can be used for the supervised machine learning algorithm

# %% [markdown]
# ## Date-Time Features Method

# %% [markdown]
# #### This is where we extract features from the date time index such as monthly data, daily data like that.But these alone are not sufficient for a good machine learning model. We also have many other features that we can consider such as: Minutes elapsed for the day, Hour of day, Business hours or not,  Weekend or not.

# %%
import pandas as pd
data = pd.read_csv('daily-minimum-temperatures-in-me.csv',header = 0,parse_dates=True,index_col=0)
data.squeeze("columns")
data
# Out:
#             Daily minimum temperatures
# Date
# 1981-01-01                        20.7
# 1981-01-02                        17.9
# 1981-01-03                        18.8
# 1981-01-04                        14.6
# 1981-01-05                        15.8
# ...                                ...
# 1990-12-27                        14.0
# 1990-12-28                        13.6
# 1990-12-29                        13.5
# 1990-12-30                        15.7
# 1990-12-31                        13.0
#
# [3650 rows x 1 columns]

# %%
df = pd.DataFrame()

# %%
df['Months'] = [i.month for i in data.index]
df['Days'] = [i.day for i in data.index]
df['Temperature'] = [i for i in data.loc[:,'Daily minimum temperatures']]
df
# Out:
#       Months  Days  Temperature
# 0          1     1         20.7
# 1          1     2         17.9
# 2          1     3         18.8
# 3          1     4         14.6
# 4          1     5         15.8
# ...      ...   ...          ...
# 3645      12    27         14.0
# 3646      12    28         13.6
# 3647      12    29         13.5
# 3648      12    30         15.7
# 3649      12    31         13.0
#
# [3650 rows x 3 columns]

# %% [markdown]
# ## Lag Feautres Method

# %% [markdown]
# #### The simplest approach is to predict the value at the next time (t+1) given the value at the current time(t).

# %%
import pandas as pd
dataset = pd.read_csv('daily-minimum-temperatures-in-me.csv',parse_dates = True,header = 0,index_col = 0)
dataset.squeeze("columns")
dataset
# Out:
#             Daily minimum temperatures
# Date
# 1981-01-01                        20.7
# 1981-01-02                        17.9
# 1981-01-03                        18.8
# 1981-01-04                        14.6
# 1981-01-05                        15.8
# ...                                ...
# 1990-12-27                        14.0
# 1990-12-28                        13.6
# 1990-12-29                        13.5
# 1990-12-30                        15.7
# 1990-12-31                        13.0
#
# [3650 rows x 1 columns]

# %%
dataframe = pd.DataFrame(dataset.values)
dataframe = pd.concat([dataframe.shift(1),dataframe],axis=1)
dataframe.columns = ['t-1','t']
dataframe
# Out:
#        t-1     t
# 0      NaN  20.7
# 1     20.7  17.9
# 2     17.9  18.8
# 3     18.8  14.6
# 4     14.6  15.8
# ...    ...   ...
# 3645  14.6  14.0
# 3646  14.0  13.6
# 3647  13.6  13.5
# 3648  13.5  15.7
# 3649  15.7  13.0
#
# [3650 rows x 2 columns]

# %% [markdown]
# #### Trying with a window width of 3

# %%
df = pd.DataFrame(dataset.values)
df = pd.concat([df.shift(3),df.shift(2),df.shift(1),df],axis=1)
df.columns = ['t-3','t-2','t-1','t']
df
# Out:
#        t-3   t-2   t-1     t
# 0      NaN   NaN   NaN  20.7
# 1      NaN   NaN  20.7  17.9
# 2      NaN  20.7  17.9  18.8
# 3     20.7  17.9  18.8  14.6
# 4     17.9  18.8  14.6  15.8
# ...    ...   ...   ...   ...
# 3645  10.0  12.9  14.6  14.0
# 3646  12.9  14.6  14.0  13.6
# 3647  14.6  14.0  13.6  13.5
# 3648  14.0  13.6  13.5  15.7
# 3649  13.6  13.5  15.7  13.0
#
# [3650 rows x 4 columns]

# %% [markdown]
# ## Rolling Window Method

# %% [markdown]
# ##### In this method basically instead of taking the lag values we take the previous time steps statistics such as mean which actually is called as rolling mean.

# %%
dataset = pd.read_csv('daily-minimum-temperatures-in-me.csv',parse_dates = True,index_col = 0,header=0)
dataset.squeeze("columns")
df = pd.DataFrame(dataset.values)
shifted = df.shift(1)
windows = shifted.rolling(window=2)
means = windows.mean()
dataframe = pd.concat([means,df],axis=1)
dataframe.columns = ['mean(t-1,t)','t+1']
dataframe
# Out:
#       mean(t-1,t)   t+1
# 0             NaN  20.7
# 1             NaN  17.9
# 2           19.30  18.8
# 3           18.35  14.6
# 4           16.70  15.8
# ...           ...   ...
# 3645        13.75  14.0
# 3646        14.30  13.6
# 3647        13.80  13.5
# 3648        13.55  15.7
# 3649        14.60  13.0
#
# [3650 rows x 2 columns]

# %% [markdown]
# ##### More window statistics that can be performed are: min, max, mean
# #### If the window size is n then the shifting should be done by (n-1)

# %%
dataset = pd.read_csv('daily-minimum-temperatures-in-me.csv',header=0,index_col=0,parse_dates=True)
dataset.squeeze("columns")
dataset = pd.DataFrame(dataset.values)
shifted = dataset.shift(2)
windows = shifted.rolling(window=3)
dataframe = pd.concat([windows.min(),windows.mean(),windows.max(),dataset],axis=1)
dataframe.columns = ['min','mean','max','t+1']
dataframe
# Out:
#        min       mean   max   t+1
# 0      NaN        NaN   NaN  20.7
# 1      NaN        NaN   NaN  17.9
# 2      NaN        NaN   NaN  18.8
# 3      NaN        NaN   NaN  14.6
# 4     17.9  19.133333  20.7  15.8
# ...    ...        ...   ...   ...
# 3645  10.0  12.266667  13.9  14.0
# 3646  10.0  12.500000  14.6  13.6
# 3647  12.9  13.833333  14.6  13.5
# 3648  13.6  14.066667  14.6  15.7
# 3649  13.5  13.700000  14.0  13.0
#
# [3650 rows x 4 columns]

# %% [markdown]
# ## Expanding Window Statistics

# %% [markdown]
# #### In this basically we will be keeping track of all the previous values

# %%
dataset = pd.read_csv('daily-minimum-temperatures-in-me.csv',header=0,index_col=0,parse_dates=True)
dataset.squeeze("columns")
dataframe = pd.DataFrame(dataset.values)
windows = dataframe.expanding() # notice how we didn't shift the dataframe before expanding unlike rolling window
dataframe = pd.concat([windows.min(),windows.mean(),windows.max(),dataframe.shift(-1)],axis=1)
dataframe.columns = ['min','mean','max','t+1']
dataframe
# Out:
#        min       mean   max   t+1
# 0     20.7  20.700000  20.7  17.9
# 1     17.9  19.300000  20.7  18.8
# 2     17.9  19.133333  20.7  14.6
# 3     14.6  18.000000  20.7  15.8
# 4     14.6  17.560000  20.7  15.8
# ...    ...        ...   ...   ...
# 3645   0.0  11.174712  26.3  13.6
# 3646   0.0  11.175377  26.3  13.5
# 3647   0.0  11.176014  26.3  15.7
# 3648   0.0  11.177254  26.3  13.0
# 3649   0.0  11.177753  26.3   NaN
#
# [3650 rows x 4 columns]
