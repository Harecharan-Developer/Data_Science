# %% [markdown]
# PRACTICE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\DELL\\DESKTOP\\5TH SEM\\Fundamentals_of_Data_Science\\IPythonNotebook\\Faulty_dataset.csv')
df
# Out:
#     slno                name            rollno      contact   gender  \
# 0      1                 NaN  CB.EN.U4CYS21067  9.110334e+09    Male
# 1      2   Ch.Madhav Dheeraj  CB.EN.U4CSE21611  9.553435e+09    Male
# 2      3  Manbendra Satpathy  CB.EN.U4CYS21039  9.777512e+09    Male
# 3      4                 NaN  CH.EN.U4CYS21063  6.304027e+09  Female
# 4      5   M.L.Sahasra Reddy  CH.EN.U4CYS21037  6.303988e+09  Female
# ..   ...                 ...               ...           ...     ...
# 81    79   Alagu Soundarya G  CB.EN.U4CYS21005  9.345533e+09  Female
# 82    71   Yuvaraj Kumar G P  CB.EN.U4CYS21090  9.384310e+09     NaN
# 83    71   Yuvaraj Kumar G P  CB.EN.U4CYS21090  9.384310e+09     NaN
# 84    71   Yuvaraj Kumar G P  CB.EN.U4CYS21090  9.384310e+09     NaN
# 85    71   Yuvaraj Kumar G P  CB.EN.U4CYS21090  9.384310e+09     NaN
#
#            dob      10th  12th                    COLLEGE  Current Course  \
# ...
